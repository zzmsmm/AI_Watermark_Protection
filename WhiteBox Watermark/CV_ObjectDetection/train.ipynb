# %%
import os
import numpy as np
import itertools
from engine import train_one_epoch, evaluate
import utils
import transforms as T

import torch
from PIL import Image
import copy
import itertools
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

import torch.utils.data as Data
from torch.utils.data import Dataset
n=200
torch.manual_seed(516)
torch.cuda.manual_seed_all(516)

# %%
class QRDataset(Dataset):
    def __init__(self, txt_path, transform = None, target_transform = None):
        fh = open(txt_path, 'r')
        imgs = []
        for line in fh:
             line.rstrip()
             words= line.split()
             imgs.append((words[0], int(words[1])))
        self.imgs = imgs 
        self.transform = transform
        self.target_transform = target_transform
    def __getitem__(self, index):
        fn, label = self.imgs[index]
        img = Image.open(fn).convert('RGB') 
        if self.transform is not None:
            img = self.transform(img) 
        return img, label
    def __len__(self):
	      return len(self.imgs)

# %%
# 在训练模型之前，需要写好数据集的载入接口。
 
class PennFudanDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms=None):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))
 
    def __getitem__(self, idx):
        # load images ad masks
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
        img = Image.open(img_path).convert("RGB")
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance with 0 being background
        mask = Image.open(mask_path)
 
        mask = np.array(mask)
        # instances are encoded as different colors
        obj_ids = np.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]
 
        # split the color-encoded mask into a set of binary masks
        masks = mask == obj_ids[:, None, None]
 
        # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])
 
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)
 
        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)
 
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
 
        if self.transforms is not None:
            img, target = self.transforms(img, target)
 
        return img, target
 
    def __len__(self):
        return len(self.imgs)

# %%
def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %%
def verify_acc(model,Cwm,qr_host_loader):
    error_count=0
    for step,(b_x,b_y) in enumerate(qr_host_loader):
        b_x=b_x.to(device)
        b_y=b_y.to(device)
        z=model.backbone.body.conv1(b_x)
        z=model.backbone.body.bn1(z)
        z=model.backbone.body.relu(z)
        z=model.backbone.body.maxpool(z)
        z1=model.backbone.body.layer1(z)
        z2=model.backbone.body.layer2(z1)
        z3=model.backbone.body.layer3(z2)
        z4=model.backbone.body.layer4(z3)
        z1=F.avg_pool2d(z1,4)
        z1=z1.view(z1.size(0),-1)
        z2=F.avg_pool2d(z2,4)
        z2=z2.view(z2.size(0),-1)
        z3=F.avg_pool2d(z3,4)
        z3=z3.view(z3.size(0),-1)
        z4=F.avg_pool2d(z4,4)
        z4=z4.view(z4.size(0),-1)
        zz=torch.cat((z1,z2,z3,z4),dim=1)
        # 把四个层（ layer+平均池化 ）的输出作为 verify 模块的输入
        op=Cwm(zz)
        for i in range(len(b_y)):
            if torch.argmax(op[i])!=b_y[i]:
                error_count=error_count+1
    return error_count/n*100.0

# %%
# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda:2') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has two classes only - background and person
num_classes = 2
# use our dataset and defined transformations
dataset = PennFudanDataset('./data/PennFudanPed', get_transform(train=True))
dataset_test = PennFudanDataset('./data/PennFudanPed', get_transform(train=False))

# split the dataset in train and test set
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-50])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=1, shuffle=True, num_workers=0,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0,
    collate_fn=utils.collate_fn)

qrdataset=QRDataset("./data/newqr/200_112/index.txt",torchvision.transforms.ToTensor())
qr_host=QRDataset("./data/newqr/200_112/index_1.txt",torchvision.transforms.ToTensor())
qr_steal=QRDataset("./data/newqr/200_112/index_2.txt",torchvision.transforms.ToTensor())
# qr_host,qr_steal=torch.utils.data.random_split(qrdataset,[int(n),int(n)])
qr_host_loader=Data.DataLoader(
    dataset=qr_host,
    batch_size=30,
    shuffle=True    
)
qr_steal_loader=Data.DataLoader(
    dataset=qr_steal,
    batch_size=16,
    shuffle=True   
)

# qrdataset=QRDataset("./data/newqr/200_112/index.txt",torchvision.transforms.ToTensor())
# qr_host,qr_steal=torch.utils.data.random_split(qrdataset,[int(n),int(n)],generator=torch.Generator().manual_seed(4396))
# qr_host_loader=Data.DataLoader( dataset=qr_host,
#                                 batch_size=30,
#                                 shuffle=True)
# qr_steal_loader=Data.DataLoader(dataset=qr_steal,
#                                 batch_size=30,
#                                 shuffle=True)

# %%
# get the model using our helper function
model = get_model_instance_segmentation(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(params, lr=0.0002,)
# and a learning rate scheduler
#lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=3,gamma=0.1)

# let's train it for 10 epochs
num_epochs = 20
for epoch in range(num_epochs):
    print("%i primary epoch in 20"% epoch)
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, 60,False)
    # update the learning rate
    # lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device,False)

train_one_epoch(model, optimizer, data_loader, device, epoch, 60,True)
evaluate(model, data_loader_test, device,True)
torch.save(model, './model/PennFudan_0.pkl')
# Out:
# 0 primary epoch in 20
# Epoch: [0]  [  0/120]  eta: 0:01:06  lr: 0.000002  loss: 5.2621 (5.2621)  loss_classifier: 0.8781 (0.8781)  loss_box_reg: 0.1849 (0.1849)  loss_mask: 4.1950 (4.1950)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.5531  data: 0.0229  max mem: 0
# Epoch: [0]  [ 60/120]  eta: 0:00:14  lr: 0.000103  loss: 0.4380 (1.4449)  loss_classifier: 0.0693 (0.2358)  loss_box_reg: 0.1449 (0.2121)  loss_mask: 0.1846 (0.9756)  loss_objectness: 0.0009 (0.0128)  loss_rpn_box_reg: 0.0066 (0.0087)  time: 0.2614  data: 0.0222  max mem: 0
# Epoch: [0]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.3339 (0.9193)  loss_classifier: 0.0379 (0.1474)  loss_box_reg: 0.0792 (0.1667)  loss_mask: 0.1943 (0.5892)  loss_objectness: 0.0008 (0.0076)  loss_rpn_box_reg: 0.0047 (0.0084)  time: 0.2524  data: 0.0194  max mem: 0
# Epoch: [0] Total time: 0:00:30 (0.2515 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:03:34  model_time: 0.0606 (0.0606)  evaluator_time: 0.0071 (0.0071)  time: 4.2917  data: 0.0110  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0827 (0.0811)  evaluator_time: 0.0049 (0.0079)  time: 0.1062  data: 0.0149  max mem: 0
# Test: Total time: 0:00:09 (0.1892 s / it)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.646
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.778
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.719
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.719
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.726
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.654
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.441
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.719
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
# 1 primary epoch in 20
# Epoch: [1]  [  0/120]  eta: 0:00:22  lr: 0.000200  loss: 0.3457 (0.3457)  loss_classifier: 0.0433 (0.0433)  loss_box_reg: 0.0835 (0.0835)  loss_mask: 0.2053 (0.2053)  loss_objectness: 0.0124 (0.0124)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 0.1837  data: 0.0357  max mem: 0
# Epoch: [1]  [ 60/120]  eta: 0:00:15  lr: 0.000200  loss: 0.2911 (0.3556)  loss_classifier: 0.0523 (0.0533)  loss_box_reg: 0.0664 (0.1097)  loss_mask: 0.1519 (0.1809)  loss_objectness: 0.0005 (0.0027)  loss_rpn_box_reg: 0.0037 (0.0089)  time: 0.2725  data: 0.0211  max mem: 0
# Epoch: [1]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.3472 (0.3797)  loss_classifier: 0.0471 (0.0567)  loss_box_reg: 0.1082 (0.1192)  loss_mask: 0.1870 (0.1896)  loss_objectness: 0.0038 (0.0047)  loss_rpn_box_reg: 0.0069 (0.0095)  time: 0.2737  data: 0.0205  max mem: 0
# Epoch: [1] Total time: 0:00:32 (0.2690 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:04  model_time: 0.0603 (0.0603)  evaluator_time: 0.0087 (0.0087)  time: 0.0807  data: 0.0111  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0820 (0.0876)  evaluator_time: 0.0053 (0.0082)  time: 0.1126  data: 0.0143  max mem: 0
# Test: Total time: 0:00:05 (0.1117 s / it)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.657
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.824
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.666
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.716
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721
# 2 primary epoch in 20
# Epoch: [2]  [  0/120]  eta: 0:00:25  lr: 0.000200  loss: 0.1886 (0.1886)  loss_classifier: 0.0260 (0.0260)  loss_box_reg: 0.0377 (0.0377)  loss_mask: 0.1204 (0.1204)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 0.2155  data: 0.0425  max mem: 0
# Epoch: [2]  [ 60/120]  eta: 0:00:16  lr: 0.000200  loss: 0.3706 (0.3791)  loss_classifier: 0.0442 (0.0624)  loss_box_reg: 0.1312 (0.1325)  loss_mask: 0.1858 (0.1708)  loss_objectness: 0.0009 (0.0040)  loss_rpn_box_reg: 0.0091 (0.0094)  time: 0.2766  data: 0.0185  max mem: 0
# Epoch: [2]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.2989 (0.3556)  loss_classifier: 0.0397 (0.0562)  loss_box_reg: 0.1075 (0.1246)  loss_mask: 0.1338 (0.1624)  loss_objectness: 0.0001 (0.0028)  loss_rpn_box_reg: 0.0059 (0.0096)  time: 0.2892  data: 0.0178  max mem: 0
# Epoch: [2] Total time: 0:00:33 (0.2775 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0561 (0.0561)  evaluator_time: 0.0052 (0.0052)  time: 0.0734  data: 0.0116  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0857 (0.0871)  evaluator_time: 0.0031 (0.0056)  time: 0.1101  data: 0.0149  max mem: 0
# Test: Total time: 0:00:05 (0.1087 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.701
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.560
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.630
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.725
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.907
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.766
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.766
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.772
# 3 primary epoch in 20
# Epoch: [3]  [  0/120]  eta: 0:00:37  lr: 0.000200  loss: 0.5115 (0.5115)  loss_classifier: 0.0515 (0.0515)  loss_box_reg: 0.2040 (0.2040)  loss_mask: 0.2434 (0.2434)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0102 (0.0102)  time: 0.3159  data: 0.0432  max mem: 0
# Epoch: [3]  [ 60/120]  eta: 0:00:16  lr: 0.000200  loss: 0.2750 (0.3007)  loss_classifier: 0.0393 (0.0409)  loss_box_reg: 0.0701 (0.0962)  loss_mask: 0.1372 (0.1521)  loss_objectness: 0.0002 (0.0030)  loss_rpn_box_reg: 0.0047 (0.0084)  time: 0.2846  data: 0.0199  max mem: 0
# Epoch: [3]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.2840 (0.3027)  loss_classifier: 0.0439 (0.0430)  loss_box_reg: 0.0823 (0.0944)  loss_mask: 0.1329 (0.1545)  loss_objectness: 0.0006 (0.0030)  loss_rpn_box_reg: 0.0039 (0.0077)  time: 0.2851  data: 0.0224  max mem: 0
# Epoch: [3] Total time: 0:00:33 (0.2823 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0564 (0.0564)  evaluator_time: 0.0052 (0.0052)  time: 0.0739  data: 0.0119  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0895 (0.0895)  evaluator_time: 0.0028 (0.0059)  time: 0.1144  data: 0.0147  max mem: 0
# Test: Total time: 0:00:05 (0.1112 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.704
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.984
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.728
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.778
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.716
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.966
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.889
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.593
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
# 4 primary epoch in 20
# Epoch: [4]  [  0/120]  eta: 0:00:28  lr: 0.000200  loss: 0.1361 (0.1361)  loss_classifier: 0.0088 (0.0088)  loss_box_reg: 0.0253 (0.0253)  loss_mask: 0.0966 (0.0966)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 0.2390  data: 0.0339  max mem: 0
# Epoch: [4]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1950 (0.2562)  loss_classifier: 0.0185 (0.0345)  loss_box_reg: 0.0627 (0.0813)  loss_mask: 0.1100 (0.1311)  loss_objectness: 0.0001 (0.0026)  loss_rpn_box_reg: 0.0051 (0.0068)  time: 0.2779  data: 0.0188  max mem: 0
# Epoch: [4]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1858 (0.2521)  loss_classifier: 0.0172 (0.0335)  loss_box_reg: 0.0494 (0.0776)  loss_mask: 0.1122 (0.1322)  loss_objectness: 0.0001 (0.0019)  loss_rpn_box_reg: 0.0043 (0.0068)  time: 0.2907  data: 0.0215  max mem: 0
# Epoch: [4] Total time: 0:00:34 (0.2858 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0581 (0.0581)  evaluator_time: 0.0054 (0.0054)  time: 0.0757  data: 0.0117  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0891 (0.0872)  evaluator_time: 0.0030 (0.0043)  time: 0.1108  data: 0.0151  max mem: 0
# Test: Total time: 0:00:05 (0.1075 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.703
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.855
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.719
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.778
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.691
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.882
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.702
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.752
# 5 primary epoch in 20
# Epoch: [5]  [  0/120]  eta: 0:00:25  lr: 0.000200  loss: 0.1402 (0.1402)  loss_classifier: 0.0097 (0.0097)  loss_box_reg: 0.0393 (0.0393)  loss_mask: 0.0886 (0.0886)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 0.2140  data: 0.0177  max mem: 0
# Epoch: [5]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.2070 (0.2101)  loss_classifier: 0.0261 (0.0260)  loss_box_reg: 0.0597 (0.0607)  loss_mask: 0.1076 (0.1166)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0049 (0.0053)  time: 0.2966  data: 0.0217  max mem: 0
# Epoch: [5]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.2058 (0.2333)  loss_classifier: 0.0253 (0.0301)  loss_box_reg: 0.0507 (0.0693)  loss_mask: 0.1291 (0.1257)  loss_objectness: 0.0005 (0.0019)  loss_rpn_box_reg: 0.0026 (0.0064)  time: 0.2852  data: 0.0179  max mem: 0
# Epoch: [5] Total time: 0:00:34 (0.2876 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0561 (0.0561)  evaluator_time: 0.0044 (0.0044)  time: 0.0717  data: 0.0107  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0893 (0.0892)  evaluator_time: 0.0029 (0.0050)  time: 0.1115  data: 0.0145  max mem: 0
# Test: Total time: 0:00:05 (0.1100 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.614
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.731
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.721
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.897
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.765
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.774
# 6 primary epoch in 20
# Epoch: [6]  [  0/120]  eta: 0:00:29  lr: 0.000200  loss: 0.1611 (0.1611)  loss_classifier: 0.0202 (0.0202)  loss_box_reg: 0.0369 (0.0369)  loss_mask: 0.1003 (0.1003)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 0.2424  data: 0.0436  max mem: 0
# Epoch: [6]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.2571 (0.2421)  loss_classifier: 0.0415 (0.0337)  loss_box_reg: 0.0694 (0.0731)  loss_mask: 0.1347 (0.1282)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0047 (0.0062)  time: 0.2889  data: 0.0204  max mem: 0
# Epoch: [6]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1897 (0.2340)  loss_classifier: 0.0223 (0.0309)  loss_box_reg: 0.0487 (0.0700)  loss_mask: 0.1082 (0.1263)  loss_objectness: 0.0001 (0.0011)  loss_rpn_box_reg: 0.0039 (0.0058)  time: 0.2905  data: 0.0207  max mem: 0
# Epoch: [6] Total time: 0:00:34 (0.2866 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0539 (0.0539)  evaluator_time: 0.0036 (0.0036)  time: 0.0709  data: 0.0129  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0917 (0.0882)  evaluator_time: 0.0025 (0.0041)  time: 0.1102  data: 0.0147  max mem: 0
# Test: Total time: 0:00:05 (0.1083 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.723
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.991
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.864
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.779
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.779
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.802
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.716
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.973
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.731
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775
# 7 primary epoch in 20
# Epoch: [7]  [  0/120]  eta: 0:00:30  lr: 0.000200  loss: 0.1633 (0.1633)  loss_classifier: 0.0258 (0.0258)  loss_box_reg: 0.0396 (0.0396)  loss_mask: 0.0895 (0.0895)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0084 (0.0084)  time: 0.2522  data: 0.0253  max mem: 0
# Epoch: [7]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1868 (0.2074)  loss_classifier: 0.0172 (0.0268)  loss_box_reg: 0.0499 (0.0584)  loss_mask: 0.0961 (0.1158)  loss_objectness: 0.0001 (0.0010)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 0.2812  data: 0.0172  max mem: 0
# Epoch: [7]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1830 (0.2113)  loss_classifier: 0.0193 (0.0259)  loss_box_reg: 0.0402 (0.0598)  loss_mask: 0.1026 (0.1191)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0038 (0.0056)  time: 0.2876  data: 0.0189  max mem: 0
# Epoch: [7] Total time: 0:00:34 (0.2887 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0538 (0.0538)  evaluator_time: 0.0040 (0.0040)  time: 0.0687  data: 0.0105  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0852 (0.0877)  evaluator_time: 0.0023 (0.0037)  time: 0.1086  data: 0.0143  max mem: 0
# Test: Total time: 0:00:05 (0.1073 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.751
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.903
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.807
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.807
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.727
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.971
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.741
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775
# 8 primary epoch in 20
# Epoch: [8]  [  0/120]  eta: 0:00:28  lr: 0.000200  loss: 0.1040 (0.1040)  loss_classifier: 0.0087 (0.0087)  loss_box_reg: 0.0202 (0.0202)  loss_mask: 0.0747 (0.0747)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 0.2358  data: 0.0154  max mem: 0
# Epoch: [8]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1739 (0.1994)  loss_classifier: 0.0152 (0.0246)  loss_box_reg: 0.0475 (0.0577)  loss_mask: 0.1024 (0.1098)  loss_objectness: 0.0002 (0.0025)  loss_rpn_box_reg: 0.0029 (0.0048)  time: 0.2892  data: 0.0182  max mem: 0
# Epoch: [8]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1722 (0.1994)  loss_classifier: 0.0255 (0.0228)  loss_box_reg: 0.0406 (0.0563)  loss_mask: 0.1151 (0.1133)  loss_objectness: 0.0003 (0.0018)  loss_rpn_box_reg: 0.0057 (0.0052)  time: 0.2979  data: 0.0222  max mem: 0
# Epoch: [8] Total time: 0:00:34 (0.2871 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0548 (0.0548)  evaluator_time: 0.0043 (0.0043)  time: 0.0710  data: 0.0115  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0884 (0.0881)  evaluator_time: 0.0021 (0.0037)  time: 0.1100  data: 0.0139  max mem: 0
# Test: Total time: 0:00:05 (0.1069 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.726
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.869
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.590
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.752
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.932
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.540
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
# 9 primary epoch in 20
# Epoch: [9]  [  0/120]  eta: 0:00:30  lr: 0.000200  loss: 0.1178 (0.1178)  loss_classifier: 0.0036 (0.0036)  loss_box_reg: 0.0233 (0.0233)  loss_mask: 0.0889 (0.0889)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 0.2539  data: 0.0264  max mem: 0
# Epoch: [9]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1675 (0.2202)  loss_classifier: 0.0213 (0.0268)  loss_box_reg: 0.0425 (0.0673)  loss_mask: 0.1014 (0.1205)  loss_objectness: 0.0002 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0045)  time: 0.2924  data: 0.0191  max mem: 0
# Epoch: [9]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1965 (0.2210)  loss_classifier: 0.0216 (0.0272)  loss_box_reg: 0.0616 (0.0663)  loss_mask: 0.1094 (0.1207)  loss_objectness: 0.0001 (0.0011)  loss_rpn_box_reg: 0.0054 (0.0058)  time: 0.2950  data: 0.0173  max mem: 0
# Epoch: [9] Total time: 0:00:34 (0.2888 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0544 (0.0544)  evaluator_time: 0.0042 (0.0042)  time: 0.0701  data: 0.0110  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0912 (0.0892)  evaluator_time: 0.0022 (0.0040)  time: 0.1095  data: 0.0138  max mem: 0
# Test: Total time: 0:00:05 (0.1081 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.739
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.883
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.813
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.796
# 10 primary epoch in 20
# Epoch: [10]  [  0/120]  eta: 0:00:41  lr: 0.000200  loss: 0.5418 (0.5418)  loss_classifier: 0.0945 (0.0945)  loss_box_reg: 0.2209 (0.2209)  loss_mask: 0.2100 (0.2100)  loss_objectness: 0.0043 (0.0043)  loss_rpn_box_reg: 0.0120 (0.0120)  time: 0.3482  data: 0.0449  max mem: 0
# Epoch: [10]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1615 (0.2010)  loss_classifier: 0.0222 (0.0257)  loss_box_reg: 0.0400 (0.0574)  loss_mask: 0.1028 (0.1117)  loss_objectness: 0.0001 (0.0009)  loss_rpn_box_reg: 0.0043 (0.0054)  time: 0.2979  data: 0.0194  max mem: 0
# Epoch: [10]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.2061 (0.2074)  loss_classifier: 0.0254 (0.0248)  loss_box_reg: 0.0523 (0.0572)  loss_mask: 0.1191 (0.1197)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0036 (0.0049)  time: 0.2837  data: 0.0174  max mem: 0
# Epoch: [10] Total time: 0:00:34 (0.2912 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0553 (0.0553)  evaluator_time: 0.0044 (0.0044)  time: 0.0715  data: 0.0113  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0928 (0.0893)  evaluator_time: 0.0023 (0.0041)  time: 0.1101  data: 0.0139  max mem: 0
# Test: Total time: 0:00:05 (0.1085 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.853
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.566
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.754
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.754
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.727
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.921
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.778
# 11 primary epoch in 20
# Epoch: [11]  [  0/120]  eta: 0:00:30  lr: 0.000200  loss: 0.1912 (0.1912)  loss_classifier: 0.0105 (0.0105)  loss_box_reg: 0.0756 (0.0756)  loss_mask: 0.1024 (0.1024)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 0.2548  data: 0.0210  max mem: 0
# Epoch: [11]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.2073 (0.2121)  loss_classifier: 0.0270 (0.0259)  loss_box_reg: 0.0535 (0.0644)  loss_mask: 0.1152 (0.1131)  loss_objectness: 0.0002 (0.0014)  loss_rpn_box_reg: 0.0039 (0.0072)  time: 0.3019  data: 0.0208  max mem: 0
# Epoch: [11]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1706 (0.2003)  loss_classifier: 0.0148 (0.0244)  loss_box_reg: 0.0249 (0.0575)  loss_mask: 0.0990 (0.1108)  loss_objectness: 0.0000 (0.0012)  loss_rpn_box_reg: 0.0025 (0.0064)  time: 0.2827  data: 0.0150  max mem: 0
# Epoch: [11] Total time: 0:00:34 (0.2889 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0562 (0.0562)  evaluator_time: 0.0050 (0.0050)  time: 0.0727  data: 0.0111  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0927 (0.0899)  evaluator_time: 0.0025 (0.0039)  time: 0.1101  data: 0.0139  max mem: 0
# Test: Total time: 0:00:05 (0.1088 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.720
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.852
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.768
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.768
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.709
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.630
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775
# 12 primary epoch in 20
# Epoch: [12]  [  0/120]  eta: 0:00:36  lr: 0.000200  loss: 0.3256 (0.3256)  loss_classifier: 0.0382 (0.0382)  loss_box_reg: 0.1017 (0.1017)  loss_mask: 0.1796 (0.1796)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 0.3032  data: 0.0490  max mem: 0
# Epoch: [12]  [ 60/120]  eta: 0:00:16  lr: 0.000200  loss: 0.1314 (0.1710)  loss_classifier: 0.0127 (0.0180)  loss_box_reg: 0.0208 (0.0407)  loss_mask: 0.1006 (0.1073)  loss_objectness: 0.0001 (0.0011)  loss_rpn_box_reg: 0.0015 (0.0039)  time: 0.2794  data: 0.0148  max mem: 0
# Epoch: [12]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.4475 (0.2250)  loss_classifier: 0.0493 (0.0256)  loss_box_reg: 0.0881 (0.0559)  loss_mask: 0.2231 (0.1354)  loss_objectness: 0.0036 (0.0026)  loss_rpn_box_reg: 0.0097 (0.0055)  time: 0.2990  data: 0.0188  max mem: 0
# Epoch: [12] Total time: 0:00:34 (0.2890 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0570 (0.0570)  evaluator_time: 0.0057 (0.0057)  time: 0.0742  data: 0.0110  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0966 (0.0945)  evaluator_time: 0.0070 (0.0086)  time: 0.1188  data: 0.0142  max mem: 0
# Test: Total time: 0:00:05 (0.1183 s / it)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.600
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.723
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.634
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.708
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.678
# 13 primary epoch in 20
# Epoch: [13]  [  0/120]  eta: 0:00:31  lr: 0.000200  loss: 0.2971 (0.2971)  loss_classifier: 0.0243 (0.0243)  loss_box_reg: 0.1034 (0.1034)  loss_mask: 0.1380 (0.1380)  loss_objectness: 0.0172 (0.0172)  loss_rpn_box_reg: 0.0142 (0.0142)  time: 0.2656  data: 0.0435  max mem: 0
# Epoch: [13]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.2179 (0.3141)  loss_classifier: 0.0321 (0.0400)  loss_box_reg: 0.0605 (0.0858)  loss_mask: 0.1345 (0.1753)  loss_objectness: 0.0001 (0.0047)  loss_rpn_box_reg: 0.0048 (0.0083)  time: 0.2913  data: 0.0174  max mem: 0
# Epoch: [13]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1822 (0.2975)  loss_classifier: 0.0262 (0.0386)  loss_box_reg: 0.0530 (0.0851)  loss_mask: 0.1045 (0.1622)  loss_objectness: 0.0002 (0.0038)  loss_rpn_box_reg: 0.0025 (0.0077)  time: 0.2950  data: 0.0181  max mem: 0
# Epoch: [13] Total time: 0:00:34 (0.2912 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0541 (0.0541)  evaluator_time: 0.0039 (0.0039)  time: 0.0693  data: 0.0108  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0865 (0.0882)  evaluator_time: 0.0023 (0.0036)  time: 0.1080  data: 0.0141  max mem: 0
# Test: Total time: 0:00:05 (0.1068 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.683
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.962
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.825
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.457
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.706
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.752
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.752
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.769
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.962
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.844
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.769
# 14 primary epoch in 20
# Epoch: [14]  [  0/120]  eta: 0:00:30  lr: 0.000200  loss: 0.1662 (0.1662)  loss_classifier: 0.0416 (0.0416)  loss_box_reg: 0.0384 (0.0384)  loss_mask: 0.0842 (0.0842)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.2525  data: 0.0274  max mem: 0
# Epoch: [14]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1962 (0.2043)  loss_classifier: 0.0166 (0.0251)  loss_box_reg: 0.0489 (0.0555)  loss_mask: 0.1152 (0.1170)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0049 (0.0062)  time: 0.2921  data: 0.0166  max mem: 0
# Epoch: [14]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1454 (0.2034)  loss_classifier: 0.0129 (0.0246)  loss_box_reg: 0.0310 (0.0571)  loss_mask: 0.1031 (0.1149)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0036 (0.0058)  time: 0.2809  data: 0.0189  max mem: 0
# Epoch: [14] Total time: 0:00:34 (0.2896 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0554 (0.0554)  evaluator_time: 0.0046 (0.0046)  time: 0.0717  data: 0.0112  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0871 (0.0886)  evaluator_time: 0.0023 (0.0034)  time: 0.1083  data: 0.0144  max mem: 0
# Test: Total time: 0:00:05 (0.1074 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.972
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.870
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775
# ...
# Epoch: [16]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1282 (0.1750)  loss_classifier: 0.0146 (0.0201)  loss_box_reg: 0.0373 (0.0483)  loss_mask: 0.0871 (0.1008)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0019 (0.0047)  time: 0.2866  data: 0.0193  max mem: 0
# Epoch: [16] Total time: 0:00:34 (0.2906 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0529 (0.0529)  evaluator_time: 0.0032 (0.0032)  time: 0.0680  data: 0.0114  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0860 (0.0893)  evaluator_time: 0.0021 (0.0036)  time: 0.1093  data: 0.0141  max mem: 0
# Test: Total time: 0:00:05 (0.1080 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.849
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.600
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.773
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.773
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.782
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.620
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.786
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.786
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.793
# 17 primary epoch in 20
# Epoch: [17]  [  0/120]  eta: 0:00:30  lr: 0.000200  loss: 0.2501 (0.2501)  loss_classifier: 0.0483 (0.0483)  loss_box_reg: 0.0854 (0.0854)  loss_mask: 0.0893 (0.0893)  loss_objectness: 0.0228 (0.0228)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 0.2536  data: 0.0265  max mem: 0
# Epoch: [17]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1296 (0.1697)  loss_classifier: 0.0116 (0.0187)  loss_box_reg: 0.0287 (0.0479)  loss_mask: 0.0872 (0.0989)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0015 (0.0034)  time: 0.2893  data: 0.0162  max mem: 0
# Epoch: [17]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1557 (0.1709)  loss_classifier: 0.0202 (0.0191)  loss_box_reg: 0.0362 (0.0468)  loss_mask: 0.0939 (0.1005)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0037)  time: 0.2912  data: 0.0213  max mem: 0
# Epoch: [17] Total time: 0:00:35 (0.2921 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0539 (0.0539)  evaluator_time: 0.0033 (0.0033)  time: 0.0686  data: 0.0110  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0850 (0.0878)  evaluator_time: 0.0020 (0.0034)  time: 0.1078  data: 0.0141  max mem: 0
# Test: Total time: 0:00:05 (0.1063 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.779
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.575
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.795
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.361
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.740
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.899
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.755
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.786
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.786
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# 18 primary epoch in 20
# Epoch: [18]  [  0/120]  eta: 0:00:28  lr: 0.000200  loss: 0.1144 (0.1144)  loss_classifier: 0.0121 (0.0121)  loss_box_reg: 0.0110 (0.0110)  loss_mask: 0.0894 (0.0894)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.2411  data: 0.0159  max mem: 0
# Epoch: [18]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1400 (0.1568)  loss_classifier: 0.0189 (0.0166)  loss_box_reg: 0.0300 (0.0423)  loss_mask: 0.0895 (0.0941)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0026 (0.0034)  time: 0.2991  data: 0.0212  max mem: 0
# Epoch: [18]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1318 (0.1559)  loss_classifier: 0.0154 (0.0178)  loss_box_reg: 0.0262 (0.0394)  loss_mask: 0.0866 (0.0953)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0012 (0.0032)  time: 0.2965  data: 0.0176  max mem: 0
# Epoch: [18] Total time: 0:00:34 (0.2913 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0522 (0.0522)  evaluator_time: 0.0030 (0.0030)  time: 0.0675  data: 0.0118  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0859 (0.0878)  evaluator_time: 0.0020 (0.0032)  time: 0.1082  data: 0.0142  max mem: 0
# Test: Total time: 0:00:05 (0.1061 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.755
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.975
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.916
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.768
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.807
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.738
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.975
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.529
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.749
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.777
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.777
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.784
# 19 primary epoch in 20
# Epoch: [19]  [  0/120]  eta: 0:00:28  lr: 0.000200  loss: 0.1457 (0.1457)  loss_classifier: 0.0128 (0.0128)  loss_box_reg: 0.0466 (0.0466)  loss_mask: 0.0827 (0.0827)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 0.2399  data: 0.0303  max mem: 0
# Epoch: [19]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1339 (0.1472)  loss_classifier: 0.0106 (0.0155)  loss_box_reg: 0.0300 (0.0350)  loss_mask: 0.0908 (0.0935)  loss_objectness: 0.0000 (0.0003)  loss_rpn_box_reg: 0.0028 (0.0029)  time: 0.2939  data: 0.0198  max mem: 0
# Epoch: [19]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1349 (0.1475)  loss_classifier: 0.0133 (0.0156)  loss_box_reg: 0.0284 (0.0345)  loss_mask: 0.0904 (0.0938)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0022 (0.0031)  time: 0.2896  data: 0.0179  max mem: 0
# Epoch: [19] Total time: 0:00:34 (0.2895 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0532 (0.0532)  evaluator_time: 0.0035 (0.0035)  time: 0.0679  data: 0.0107  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0868 (0.0886)  evaluator_time: 0.0021 (0.0034)  time: 0.1077  data: 0.0139  max mem: 0
# Test: Total time: 0:00:05 (0.1070 s / it)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.778
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.974
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.916
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.536
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.846
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.877
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.545
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.766
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.794
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.794
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.803
# Epoch: [19]  [  0/120]  eta: 0:00:34  lr: 0.000200  loss: 0.1525 (0.1525)  loss_classifier: 0.0191 (0.0191)  loss_box_reg: 0.0279 (0.0279)  loss_mask: 0.0846 (0.0846)  loss_objectness: 0.0159 (0.0159)  loss_rpn_box_reg: 0.0050 (0.0050)  time: 0.2891  data: 0.0226  max mem: 0
# Epoch: [19]  [ 60/120]  eta: 0:00:17  lr: 0.000200  loss: 0.1213 (0.1457)  loss_classifier: 0.0135 (0.0151)  loss_box_reg: 0.0250 (0.0339)  loss_mask: 0.0875 (0.0933)  loss_objectness: 0.0000 (0.0004)  loss_rpn_box_reg: 0.0028 (0.0029)  time: 0.2870  data: 0.0150  max mem: 0
# Epoch: [19]  [119/120]  eta: 0:00:00  lr: 0.000200  loss: 0.1242 (0.1467)  loss_classifier: 0.0114 (0.0157)  loss_box_reg: 0.0270 (0.0352)  loss_mask: 0.0877 (0.0922)  loss_objectness: 0.0000 (0.0005)  loss_rpn_box_reg: 0.0016 (0.0031)  time: 0.2984  data: 0.0194  max mem: 0
# Epoch: [19] Total time: 0:00:34 (0.2910 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:03  model_time: 0.0528 (0.0528)  evaluator_time: 0.0031 (0.0031)  time: 0.0675  data: 0.0111  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0878 (0.0885)  evaluator_time: 0.0022 (0.0033)  time: 0.1084  data: 0.0142  max mem: 0
# Test: Total time: 0:00:05 (0.1070 s / it)
# Averaged stats: model_time: 0.0878 (0.0885)  evaluator_time: 0.0022 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.727
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.789
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.922
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.798

# %%
model = torch.load('./model/PennFudan_0.pkl')
Cwm=nn.Sequential(
    nn.Linear(20224,256),
    nn.ReLU(),
    nn.Linear(256,2))
Cwm=Cwm.to(device)
loss_function=nn.CrossEntropyLoss()
optimizer_=Adam(Cwm.parameters(),lr=0.0001)
conv1_p=[]
for param in model.backbone.body.conv1.parameters():
    temp=copy.deepcopy(param)
    conv1_p.append(temp)
layer1_p=[]
for param in model.backbone.body.layer1.parameters():
    temp=copy.deepcopy(param)
    layer1_p.append(param)
layer2_p=[]
for param in model.backbone.body.layer2.parameters():
    temp=copy.deepcopy(param)
    layer2_p.append(param)
layer3_p=[]
for param in model.backbone.body.layer3.parameters():
    temp=copy.deepcopy(param)
    layer3_p.append(param)
layer4_p=[]
for param in model.backbone.body.layer4.parameters():
    temp=copy.deepcopy(param)
    layer4_p.append(param)

epoch=500
DA=False
embed_history=[]
for e in range(epoch):
    # va=verify_acc(model,Cwm,qr_host_loader)
    # print(va)
    # embed_history.append(va)
    if (e>epoch*0.5) and (e%50==0) and DA:
        mm=copy.deepcopy(model)
        mm=mm.to(device)
        mm_optimizer=Adam([p for p in mm.parameters() if p.requires_grad],lr=0.0002)
        train_one_epoch(mm, mm_optimizer, data_loader, device, e, 60,False)
        for ie in range(20):
            for step,(b_x,b_y) in enumerate(qr_host_loader):
                b_x=b_x.to(device)
                b_y=b_y.to(device)
                z=mm.backbone.body.conv1(b_x)
                z=mm.backbone.body.bn1(z)
                z=mm.backbone.body.relu(z)
                z=mm.backbone.body.maxpool(z)
                z1=mm.backbone.body.layer1(z)
                z2=mm.backbone.body.layer2(z1)
                z3=mm.backbone.body.layer3(z2)
                z4=mm.backbone.body.layer4(z3)
                z1=F.avg_pool2d(z1,4)
                z1=z1.view(z1.size(0),-1)
                z2=F.avg_pool2d(z2,4)
                z2=z2.view(z2.size(0),-1)
                z3=F.avg_pool2d(z3,4)
                z3=z3.view(z3.size(0),-1)
                z4=F.avg_pool2d(z4,4)
                z4=z4.view(z4.size(0),-1)
                zz=torch.cat((z1,z2,z3,z4),dim=1)
                op=Cwm(zz)
                loss=loss_function(op,b_y)
                optimizer_.zero_grad()
                loss.backward()
                optimizer_.step()
    else:
        for step,(b_x,b_y) in enumerate(qr_host_loader):
            b_x=b_x.to(device)
            b_y=b_y.to(device)
            z=model.backbone.body.conv1(b_x)
            z=model.backbone.body.bn1(z)
            z=model.backbone.body.relu(z)
            z=model.backbone.body.maxpool(z)
            z1=model.backbone.body.layer1(z)
            z2=model.backbone.body.layer2(z1)
            z3=model.backbone.body.layer3(z2)
            z4=model.backbone.body.layer4(z3)
            z1=F.avg_pool2d(z1,4)
            z1=z1.view(z1.size(0),-1)
            z2=F.avg_pool2d(z2,4)
            z2=z2.view(z2.size(0),-1)
            z3=F.avg_pool2d(z3,4)
            z3=z3.view(z3.size(0),-1)
            z4=F.avg_pool2d(z4,4)
            z4=z4.view(z4.size(0),-1)
            zz=torch.cat((z1,z2,z3,z4),dim=1)
            op=Cwm(zz)
            loss=loss_function(op,b_y)
            optimizer_.zero_grad()
            loss.backward()
            optimizer_.step()
    if (e%100==0):
        print("Accuracy=%f, %i in %i epochs"%(verify_acc(model,Cwm,qr_host_loader),e,epoch))
        print(loss)
        #evaluate(model,data_loader_test,device,True)
print("Embedding terminates.-------------------------------------------------------------")
evaluate(model,data_loader_test,device,True)
# print("-------------------------------------------------------------------------")
# ft_record=[]

# for e in range(10):
#     train_one_epoch(model, optimizer, data_loader, device, e, 60,True)
#     evaluate(model, data_loader_test,device, True)
#     v=verify_acc(model,Cwm,qr_host_loader)
#     ft_record.append(v)
#     print("FT epoch %i, acc = %f" % (e,v))
#     print("------------------------------------------------------------------")

# print("That's it!")
# print(embed_history)
# print(ft_record)
# Out:
# Accuracy=50.000000, 0 in 500 epochs
# tensor(0.6985, device='cuda:2', grad_fn=<NllLossBackward>)
# Accuracy=26.500000, 100 in 500 epochs
# tensor(0.5201, device='cuda:2', grad_fn=<NllLossBackward>)
# Accuracy=13.500000, 200 in 500 epochs
# tensor(0.3841, device='cuda:2', grad_fn=<NllLossBackward>)
# Accuracy=2.500000, 300 in 500 epochs
# tensor(0.3191, device='cuda:2', grad_fn=<NllLossBackward>)
# Accuracy=0.500000, 400 in 500 epochs
# tensor(0.1275, device='cuda:2', grad_fn=<NllLossBackward>)
# Embedding terminates.-------------------------------------------------------------
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:04  model_time: 0.0679 (0.0679)  evaluator_time: 0.0026 (0.0026)  time: 0.0845  data: 0.0132  max mem: 0
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0927 (0.0877)  evaluator_time: 0.0033 (0.0036)  time: 0.1117  data: 0.0157  max mem: 0
# Test: Total time: 0:00:05 (0.1081 s / it)
# Averaged stats: model_time: 0.0927 (0.0877)  evaluator_time: 0.0033 (0.0036)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.974
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.855
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.765
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.806
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.828
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.954
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.734
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.859

# %%
error_count=0
for step,(b_x,b_y) in enumerate(qr_host_loader):
    b_x=b_x.to(device)
    b_y=b_y.to(device)
    z=model.backbone.body.conv1(b_x)
    z=model.backbone.body.bn1(z)
    z=model.backbone.body.relu(z)
    z=model.backbone.body.maxpool(z)
    z1=model.backbone.body.layer1(z)
    z2=model.backbone.body.layer2(z1)
    z3=model.backbone.body.layer3(z2)
    z4=model.backbone.body.layer4(z3)
    z1=F.avg_pool2d(z1,4)
    z1=z1.view(z1.size(0),-1)
    z2=F.avg_pool2d(z2,4)
    z2=z2.view(z2.size(0),-1)
    z3=F.avg_pool2d(z3,4)
    z3=z3.view(z3.size(0),-1)
    z4=F.avg_pool2d(z4,4)
    z4=z4.view(z4.size(0),-1)
    zz=torch.cat((z1,z2,z3,z4),dim=1)
    ans=Cwm(zz)
    for i in range(len(b_y)):
        if torch.argmax(ans[i])!=b_y[i]:
            error_count=error_count+1
print(error_count/n*100.0)
# Out:
# 0.0
